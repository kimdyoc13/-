# %% [markdown]
# # 1. 시각화를 시작하며 - 맷플롯립과 시본 개요

# %% [markdown]
# # 2. 맷플롯립(Matplotlib)

# %% [markdown]
# ## 맷플롯립의 pyplot 모듈의 이해

# %%
# pyplot 모듈을 (관용적으로) plt 라는 이름으로 import.
import matplotlib.pyplot as plt

# x 축 입력값[1, 2, 3] , y 축 입력값 [2, 4, 6] 으로 선 그래프 생성.
plt.plot([1, 2, 3], [2, 4, 6])

# 선 그래프 타이틀을 Hello plot 으로 설정.
plt.title("Hello plot") 

# 선 그래프를 출력
plt.show()

# %% [markdown]
# ## pyplot의 두 가지 중요 요소 - Figure 와 Axes 이해

# %% [markdown]
# ## Figure 와 Axis 의 활용

# %%
# plt.figure() 는 주로 figure 의 크기를 조절하는 데 사용됨.
# 아래의 figure 크기가 가로 10, 세로 4 인 Figure 객체를 걸정하고 반환함.

plt.figure(figsize = (10, 4))
plt.plot([1, 2, 3,], [2, 4, 6])
plt.title("Hello plot")
plt.show()

# %%
figure = plt.figure(figsize = (10, 4))  
print(type(figure))
# Out:
# <class 'matplotlib.figure.Figure'>

# %%
# plt.figure() 는 주로 figure 의 크기를 조절하는 데 사용됨.
# 아래의 figure 크기가 가로 10, 세로 4 인 Figure 객체를 걸정하고 반환함.

plt.figure(figsize = (4, 4), facecolor = 'yellow')
plt.plot([1, 2, 3,], [2, 4, 6])
plt.title("Hello plot")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (4, 4))
 
# Axes 객체의 plot() 이용하여 선 그래프를 그림
ax.plot([1, 2, 3], [2, 4, 6])

# Axes 객체의 set_title() 을 이용하여 선 그래프 타이틀을 Hello plot 으로 설정.
ax.set_title('Hello plot')
plt.show()

# %% [markdown]
# ## 여러 개의 plot을 가지는 subplot들을 생성하기
